# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Cruide Oil WTI

# %% [markdown]
# ## 7:3

# %%
df= pd.read_csv('Crude Oil WTI Futures Historical Data.csv')
df = df.dropna() # Drop missing values

# %% [markdown]
# ### Các hàm chuyển kiểu dữ liệu cho Vol, Change, Date

# %%
def convert_volume_to_number(volume_str):
    if isinstance(volume_str, float):
        return volume_str
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    else:
        return volume_str


def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%'))
    return new_change

def convert_str_to_number(str):
    return float(str.replace(',', ''))

df['Vol.'] = df['Vol.'] .apply(convert_volume_to_number)
df['Change %'] = df['Change %'].apply(convert_change_to_number)
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1296 entries, 0 to 1383
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1296 non-null   datetime64[ns]
#  1   Price     1296 non-null   float64
#  2   Open      1296 non-null   float64
#  3   High      1296 non-null   float64
#  4   Low       1296 non-null   float64
#  5   Vol.      1296 non-null   int64
#  6   Change %  1296 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 81.0 KB

# %% [markdown]
# ### Tạo hàm Eval

# %%
def eval(test,pred):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

# %%
# Chuyển đổi cột 'Price' thành mảng NumPy
df = df[['Price']]
df = df.dropna() # Drop missing values
df = df.reset_index(drop=True) # Reset the index
df
# Out:
#       Price
# 0     81.35
# 1     81.62
# 2     81.95
# 3     80.63
# 4     81.07
# ...     ...
# 1291  49.78
# 1292  48.52
# 1293  47.96
# 1294  47.09
# 1295  46.54
#
# [1296 rows x 1 columns]

# %% [markdown]
# ### Train, Test

# %%
# Split the data into training, testing, and validation sets
train_size = int(0.7 * len(df))
test_size = len(df)-train_size
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]

# %% [markdown]
# ### Tạo và huấn luyện mô hình

# %%
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Price'])

# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
y_pred = model.predict(x_test)

# %% [markdown]
# ### Eval

# %%
eval(y_test,y_pred)
# Out:
# ** Testing **
# MAE:  12.790090136206514
# MAPE:  36.983580900216445
# RMSE:  16.329166253701935

# %% [markdown]
# ### Predict

# %%
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# %%
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)
y_next_30_days = model.predict(x_next_30_days)

# %%
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [43.14636516 43.10857321 43.07078125 43.03298929 42.99519734 42.95740538
#  42.91961343 42.88182147 42.84402952 42.80623756 42.76844561 42.73065365
#  42.6928617  42.65506974 42.61727779 42.57948583 42.54169388 42.50390192
#  42.46610997 42.42831801 42.39052605 42.3527341  42.31494214 42.27715019
#  42.23935823 42.20156628 42.16377432 42.12598237 42.08819041 42.05039846]

# %%
plt.plot(train_data.index, train_data['Price'])
plt.plot(test_data.index, test_data['Price'])
plt.plot(test_data.index, y_pred)
plt.plot(last_data,y_next_30_days)
plt.legend(['Train', 'Test', 'Predictions','Next30Day'])
plt.show()

# %% [markdown]
# # Gasoline RBOB

# %% [markdown]
# ## 7:3

# %%
df= pd.read_csv('Gasoline RBOB Futures Historical Data.csv')
df = df.dropna() # Drop missing values

# %% [markdown]
# ### Các hàm chuyển kiểu dữ liệu cho Vol, Change, Date

# %%
def convert_volume_to_number(volume_str):
    if isinstance(volume_str, float):
        return volume_str
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    else:
        return volume_str


def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%'))
    return new_change

def convert_str_to_number(str):
    return float(str.replace(',', ''))

df['Vol.'] = df['Vol.'] .apply(convert_volume_to_number)
df['Change %'] = df['Change %'].apply(convert_change_to_number)
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1330 entries, 0 to 1621
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1330 non-null   datetime64[ns]
#  1   Price     1330 non-null   float64
#  2   Open      1330 non-null   float64
#  3   High      1330 non-null   float64
#  4   Low       1330 non-null   float64
#  5   Vol.      1330 non-null   int64
#  6   Change %  1330 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 83.1 KB

# %% [markdown]
# ### Tạo hàm Eval

# %%
def eval(test,pred):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

# %%
# Chuyển đổi cột 'Price' thành mảng NumPy
df = df[['Price']]
df = df.dropna() # Drop missing values
df = df.reset_index(drop=True) # Reset the index
df
# Out:
#        Price
# 0     2.6847
# 1     2.7006
# 2     2.7484
# 3     2.7398
# 4     2.7271
# ...      ...
# 1325  1.4740
# 1326  1.4505
# 1327  1.4515
# 1328  1.4377
# 1329  1.4150
#
# [1330 rows x 1 columns]

# %% [markdown]
# ### Train, Test

# %%
# Split the data into training, testing, and validation sets
train_size = int(0.7 * len(df))
test_size = len(df)-train_size
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]

# %% [markdown]
# ### Tạo và huấn luyện mô hình

# %%
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Price'])

# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
y_pred = model.predict(x_test)

# %% [markdown]
# ### Eval

# %%
eval(y_test,y_pred)
# Out:
# ** Testing **
# MAE:  0.33084655492167664
# MAPE:  24.86924212991981
# RMSE:  0.37209878050321993

# %% [markdown]
# ### Predict

# %%
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# %%
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)
y_next_30_days = model.predict(x_next_30_days)

# %%
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [0.92673352 0.92532252 0.92391153 0.92250053 0.92108953 0.91967853
#  0.91826753 0.91685653 0.91544553 0.91403453 0.91262354 0.91121254
#  0.90980154 0.90839054 0.90697954 0.90556854 0.90415754 0.90274654
#  0.90133555 0.89992455 0.89851355 0.89710255 0.89569155 0.89428055
#  0.89286955 0.89145856 0.89004756 0.88863656 0.88722556 0.88581456]

# %%
plt.plot(train_data.index, train_data['Price'])
plt.plot(test_data.index, test_data['Price'])
plt.plot(test_data.index, y_pred)
plt.plot(last_data,y_next_30_days)
plt.legend(['Train', 'Test', 'Predictions','Next30Day'])
plt.show()

# %% [markdown]
# # Heating Oil

# %% [markdown]
# ## 7:3

# %%
df= pd.read_csv('Heating Oil Futures Historical Data.csv')
df = df.dropna() # Drop missing values

# %% [markdown]
# ### Các hàm chuyển kiểu dữ liệu cho Vol, Change, Date

# %%
def convert_volume_to_number(volume_str):
    if isinstance(volume_str, float):
        return volume_str
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    else:
        return volume_str


def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%'))
    return new_change

def convert_str_to_number(str):
    return float(str.replace(',', ''))

df['Vol.'] = df['Vol.'] .apply(convert_volume_to_number)
df['Change %'] = df['Change %'].apply(convert_change_to_number)
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1319 entries, 0 to 1381
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1319 non-null   datetime64[ns]
#  1   Price     1319 non-null   float64
#  2   Open      1319 non-null   float64
#  3   High      1319 non-null   float64
#  4   Low       1319 non-null   float64
#  5   Vol.      1319 non-null   int64
#  6   Change %  1319 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 82.4 KB

# %% [markdown]
# ### Tạo hàm Eval

# %%
def eval(test,pred):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

# %%
# Chuyển đổi cột 'Price' thành mảng NumPy
df = df[['Price']]
df = df.dropna() # Drop missing values
df = df.reset_index(drop=True) # Reset the index
df
# Out:
#        Price
# 0     2.5986
# 1     2.6218
# 2     2.6786
# 3     2.6534
# 4     2.6688
# ...      ...
# 1314  1.8270
# 1315  1.7784
# 1316  1.7692
# 1317  1.7420
# 1318  1.7006
#
# [1319 rows x 1 columns]

# %% [markdown]
# ### Train, Test

# %%
# Split the data into training, testing, and validation sets
train_size = int(0.7 * len(df))
test_size = len(df)-train_size
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]

# %% [markdown]
# ### Tạo và huấn luyện mô hình

# %%
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Price'])

# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
y_pred = model.predict(x_test)

# %% [markdown]
# ### Eval

# %%
eval(y_test,y_pred)
# Out:
# ** Testing **
# MAE:  0.6078782058596436
# MAPE:  39.34636841248681
# RMSE:  0.6447377683302942

# %% [markdown]
# ### Predict

# %%
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# %%
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)
y_next_30_days = model.predict(x_next_30_days)

# %%
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [1.03498705 1.03314801 1.03130896 1.02946992 1.02763088 1.02579183
#  1.02395279 1.02211374 1.0202747  1.01843565 1.01659661 1.01475757
#  1.01291852 1.01107948 1.00924043 1.00740139 1.00556234 1.0037233
#  1.00188425 1.00004521 0.99820617 0.99636712 0.99452808 0.99268903
#  0.99084999 0.98901094 0.9871719  0.98533286 0.98349381 0.98165477]

# %%
plt.plot(train_data.index, train_data['Price'])
plt.plot(test_data.index, test_data['Price'])
plt.plot(test_data.index, y_pred)
plt.plot(last_data,y_next_30_days)
plt.legend(['Train', 'Test', 'Predictions','Next30Day'])
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Cruide Oil WTI

# %% [markdown]
# ## 8:2

# %%
df= pd.read_csv('Crude Oil WTI Futures Historical Data.csv')
df = df.dropna() # Drop missing values

# %% [markdown]
# ### Các hàm chuyển kiểu dữ liệu cho Vol, Change, Date

# %%
def convert_volume_to_number(volume_str):
    if isinstance(volume_str, float):
        return volume_str
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    else:
        return volume_str


def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%'))
    return new_change

def convert_str_to_number(str):
    return float(str.replace(',', ''))

df['Vol.'] = df['Vol.'] .apply(convert_volume_to_number)
df['Change %'] = df['Change %'].apply(convert_change_to_number)
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1296 entries, 0 to 1383
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1296 non-null   datetime64[ns]
#  1   Price     1296 non-null   float64
#  2   Open      1296 non-null   float64
#  3   High      1296 non-null   float64
#  4   Low       1296 non-null   float64
#  5   Vol.      1296 non-null   int64
#  6   Change %  1296 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 81.0 KB

# %% [markdown]
# ### Tạo hàm Eval

# %%
def eval(test,pred):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

# %%
# Chuyển đổi cột 'Price' thành mảng NumPy
df = df[['Price']]
df = df.dropna() # Drop missing values
df = df.reset_index(drop=True) # Reset the index
df
# Out:
#       Price
# 0     81.35
# 1     81.62
# 2     81.95
# 3     80.63
# 4     81.07
# ...     ...
# 1291  49.78
# 1292  48.52
# 1293  47.96
# 1294  47.09
# 1295  46.54
#
# [1296 rows x 1 columns]

# %% [markdown]
# ### Train, Test

# %%
# Split the data into training, testing, and validation sets
train_size = int(0.8 * len(df))
test_size = len(df)-train_size
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]

# %% [markdown]
# ### Tạo và huấn luyện mô hình

# %%
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Price'])

# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
y_pred = model.predict(x_test)

# %% [markdown]
# ### Eval

# %%
eval(y_test,y_pred)
# Out:
# ** Testing **
# MAE:  19.416233475997924
# MAPE:  33.766650523075825
# RMSE:  20.0194629892375

# %% [markdown]
# ### Predict

# %%
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# %%
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)
y_next_30_days = model.predict(x_next_30_days)

# %%
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [31.22349276 31.17354577 31.12359879 31.07365181 31.02370482 30.97375784
#  30.92381085 30.87386387 30.82391688 30.7739699  30.72402291 30.67407593
#  30.62412895 30.57418196 30.52423498 30.47428799 30.42434101 30.37439402
#  30.32444704 30.27450006 30.22455307 30.17460609 30.1246591  30.07471212
#  30.02476513 29.97481815 29.92487117 29.87492418 29.8249772  29.77503021]

# %%
plt.plot(train_data.index, train_data['Price'])
plt.plot(test_data.index, test_data['Price'])
plt.plot(test_data.index, y_pred)
plt.plot(last_data,y_next_30_days)
plt.legend(['Train', 'Test', 'Predictions','Next30Day'])
plt.show()

# %% [markdown]
# # Gasoline RBOB

# %% [markdown]
# ## 8:2

# %%
df= pd.read_csv('Gasoline RBOB Futures Historical Data.csv')
df = df.dropna() # Drop missing values

# %% [markdown]
# ### Các hàm chuyển kiểu dữ liệu cho Vol, Change, Date

# %%
def convert_volume_to_number(volume_str):
    if isinstance(volume_str, float):
        return volume_str
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    else:
        return volume_str


def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%'))
    return new_change

def convert_str_to_number(str):
    return float(str.replace(',', ''))

df['Vol.'] = df['Vol.'] .apply(convert_volume_to_number)
df['Change %'] = df['Change %'].apply(convert_change_to_number)
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1330 entries, 0 to 1621
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1330 non-null   datetime64[ns]
#  1   Price     1330 non-null   float64
#  2   Open      1330 non-null   float64
#  3   High      1330 non-null   float64
#  4   Low       1330 non-null   float64
#  5   Vol.      1330 non-null   int64
#  6   Change %  1330 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 83.1 KB

# %% [markdown]
# ### Tạo hàm Eval

# %%
def eval(test,pred):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

# %%
# Chuyển đổi cột 'Price' thành mảng NumPy
df = df[['Price']]
df = df.dropna() # Drop missing values
df = df.reset_index(drop=True) # Reset the index
df
# Out:
#        Price
# 0     2.6847
# 1     2.7006
# 2     2.7484
# 3     2.7398
# 4     2.7271
# ...      ...
# 1325  1.4740
# 1326  1.4505
# 1327  1.4515
# 1328  1.4377
# 1329  1.4150
#
# [1330 rows x 1 columns]

# %% [markdown]
# ### Train, Test

# %%
# Split the data into training, testing, and validation sets
train_size = int(0.8 * len(df))
test_size = len(df)-train_size
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]

# %% [markdown]
# ### Tạo và huấn luyện mô hình

# %%
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Price'])

# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
y_pred = model.predict(x_test)

# %% [markdown]
# ### Eval

# %%
eval(y_test,y_pred)
# Out:
# ** Testing **
# MAE:  0.4978171154619958
# MAPE:  33.35545125200959
# RMSE:  0.5312666796416591

# %% [markdown]
# ### Predict

# %%
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# %%
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)
y_next_30_days = model.predict(x_next_30_days)

# %%
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [0.76236867 0.76079447 0.75922027 0.75764606 0.75607186 0.75449765
#  0.75292345 0.75134924 0.74977504 0.74820083 0.74662663 0.74505242
#  0.74347822 0.74190402 0.74032981 0.73875561 0.7371814  0.7356072
#  0.73403299 0.73245879 0.73088458 0.72931038 0.72773617 0.72616197
#  0.72458776 0.72301356 0.72143936 0.71986515 0.71829095 0.71671674]

# %%
plt.plot(train_data.index, train_data['Price'])
plt.plot(test_data.index, test_data['Price'])
plt.plot(test_data.index, y_pred)
plt.plot(last_data,y_next_30_days)
plt.legend(['Train', 'Test', 'Predictions','Next30Day'])
plt.show()

# %% [markdown]
# # Heating Oil

# %% [markdown]
# ## 8:2

# %%
df= pd.read_csv('Heating Oil Futures Historical Data.csv')
df = df.dropna() # Drop missing values

# %% [markdown]
# ### Các hàm chuyển kiểu dữ liệu cho Vol, Change, Date

# %%
def convert_volume_to_number(volume_str):
    if isinstance(volume_str, float):
        return volume_str
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    else:
        return volume_str


def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%'))
    return new_change

def convert_str_to_number(str):
    return float(str.replace(',', ''))

df['Vol.'] = df['Vol.'] .apply(convert_volume_to_number)
df['Change %'] = df['Change %'].apply(convert_change_to_number)
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1319 entries, 0 to 1381
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1319 non-null   datetime64[ns]
#  1   Price     1319 non-null   float64
#  2   Open      1319 non-null   float64
#  3   High      1319 non-null   float64
#  4   Low       1319 non-null   float64
#  5   Vol.      1319 non-null   int64
#  6   Change %  1319 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 82.4 KB

# %% [markdown]
# ### Tạo hàm Eval

# %%
def eval(test,pred):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

# %%
# Chuyển đổi cột 'Price' thành mảng NumPy
df = df[['Price']]
df = df.dropna() # Drop missing values
df = df.reset_index(drop=True) # Reset the index
df
# Out:
#        Price
# 0     2.5986
# 1     2.6218
# 2     2.6786
# 3     2.6534
# 4     2.6688
# ...      ...
# 1314  1.8270
# 1315  1.7784
# 1316  1.7692
# 1317  1.7420
# 1318  1.7006
#
# [1319 rows x 1 columns]

# %% [markdown]
# ### Train, Test

# %%
# Split the data into training, testing, and validation sets
train_size = int(0.8 * len(df))
test_size = len(df)-train_size
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]

# %% [markdown]
# ### Tạo và huấn luyện mô hình

# %%
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Price'])

# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
y_pred = model.predict(x_test)

# %% [markdown]
# ### Eval

# %%
eval(y_test,y_pred)
# Out:
# ** Testing **
# MAE:  0.8958428132730107
# MAPE:  46.05836740582569
# RMSE:  0.9146753061630098

# %% [markdown]
# ### Predict

# %%
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# %%
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)
y_next_30_days = model.predict(x_next_30_days)

# %%
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [0.76502639 0.76291773 0.76080907 0.75870042 0.75659176 0.7544831
#  0.75237444 0.75026579 0.74815713 0.74604847 0.74393981 0.74183116
#  0.7397225  0.73761384 0.73550519 0.73339653 0.73128787 0.72917921
#  0.72707056 0.7249619  0.72285324 0.72074459 0.71863593 0.71652727
#  0.71441861 0.71230996 0.7102013  0.70809264 0.70598398 0.70387533]

# %%
plt.plot(train_data.index, train_data['Price'])
plt.plot(test_data.index, test_data['Price'])
plt.plot(test_data.index, y_pred)
plt.plot(last_data,y_next_30_days)
plt.legend(['Train', 'Test', 'Predictions','Next30Day'])
plt.show()

# %% [markdown]
# # Cruide Oil WTI

# %% [markdown]
# ## 9:1

# %%
df= pd.read_csv('Crude Oil WTI Futures Historical Data.csv')
df = df.dropna() # Drop missing values

# %% [markdown]
# ### Các hàm chuyển kiểu dữ liệu cho Vol, Change, Date

# %%
def convert_volume_to_number(volume_str):
    if isinstance(volume_str, float):
        return volume_str
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    else:
        return volume_str


def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%'))
    return new_change

def convert_str_to_number(str):
    return float(str.replace(',', ''))

df['Vol.'] = df['Vol.'] .apply(convert_volume_to_number)
df['Change %'] = df['Change %'].apply(convert_change_to_number)
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1296 entries, 0 to 1383
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1296 non-null   datetime64[ns]
#  1   Price     1296 non-null   float64
#  2   Open      1296 non-null   float64
#  3   High      1296 non-null   float64
#  4   Low       1296 non-null   float64
#  5   Vol.      1296 non-null   int64
#  6   Change %  1296 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 81.0 KB

# %% [markdown]
# ### Tạo hàm Eval

# %%
def eval(test,pred):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

# %%
# Chuyển đổi cột 'Price' thành mảng NumPy
df = df[['Price']]
df = df.dropna() # Drop missing values
df = df.reset_index(drop=True) # Reset the index
df
# Out:
#       Price
# 0     81.35
# 1     81.62
# 2     81.95
# 3     80.63
# 4     81.07
# ...     ...
# 1291  49.78
# 1292  48.52
# 1293  47.96
# 1294  47.09
# 1295  46.54
#
# [1296 rows x 1 columns]

# %% [markdown]
# ### Train, Test

# %%
# Split the data into training, testing, and validation sets
train_size = int(0.9 * len(df))
test_size = len(df)-train_size
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]

# %% [markdown]
# ### Tạo và huấn luyện mô hình

# %%
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Price'])

# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
y_pred = model.predict(x_test)

# %% [markdown]
# ### Eval

# %%
eval(y_test,y_pred)
# Out:
# ** Testing **
# MAE:  15.928816035743308
# MAPE:  27.368696269073965
# RMSE:  16.448760128397126

# %% [markdown]
# ### Predict

# %%
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# %%
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)
y_next_30_days = model.predict(x_next_30_days)

# %%
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [38.78400921 38.742178   38.7003468  38.65851559 38.61668439 38.57485318
#  38.53302197 38.49119077 38.44935956 38.40752836 38.36569715 38.32386594
#  38.28203474 38.24020353 38.19837233 38.15654112 38.11470991 38.07287871
#  38.0310475  37.9892163  37.94738509 37.90555389 37.86372268 37.82189147
#  37.78006027 37.73822906 37.69639786 37.65456665 37.61273544 37.57090424]

# %%
plt.plot(train_data.index, train_data['Price'])
plt.plot(test_data.index, test_data['Price'])
plt.plot(test_data.index, y_pred)
plt.plot(last_data,y_next_30_days)
plt.legend(['Train', 'Test', 'Predictions','Next30Day'])
plt.show()

# %% [markdown]
# # Gasoline RBOB

# %% [markdown]
# ## 9:1

# %%
df= pd.read_csv('Gasoline RBOB Futures Historical Data.csv')
df = df.dropna() # Drop missing values

# %% [markdown]
# ### Các hàm chuyển kiểu dữ liệu cho Vol, Change, Date

# %%
def convert_volume_to_number(volume_str):
    if isinstance(volume_str, float):
        return volume_str
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    else:
        return volume_str


def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%'))
    return new_change

def convert_str_to_number(str):
    return float(str.replace(',', ''))

df['Vol.'] = df['Vol.'] .apply(convert_volume_to_number)
df['Change %'] = df['Change %'].apply(convert_change_to_number)
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1330 entries, 0 to 1621
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1330 non-null   datetime64[ns]
#  1   Price     1330 non-null   float64
#  2   Open      1330 non-null   float64
#  3   High      1330 non-null   float64
#  4   Low       1330 non-null   float64
#  5   Vol.      1330 non-null   int64
#  6   Change %  1330 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 83.1 KB

# %% [markdown]
# ### Tạo hàm Eval

# %%
def eval(test,pred):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

# %%
# Chuyển đổi cột 'Price' thành mảng NumPy
df = df[['Price']]
df = df.dropna() # Drop missing values
df = df.reset_index(drop=True) # Reset the index
df
# Out:
#        Price
# 0     2.6847
# 1     2.7006
# 2     2.7484
# 3     2.7398
# 4     2.7271
# ...      ...
# 1325  1.4740
# 1326  1.4505
# 1327  1.4515
# 1328  1.4377
# 1329  1.4150
#
# [1330 rows x 1 columns]

# %% [markdown]
# ### Train, Test

# %%
# Split the data into training, testing, and validation sets
train_size = int(0.9 * len(df))
test_size = len(df)-train_size
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]

# %% [markdown]
# ### Tạo và huấn luyện mô hình

# %%
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Price'])

# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
y_pred = model.predict(x_test)

# %% [markdown]
# ### Eval

# %%
eval(y_test,y_pred)
# Out:
# ** Testing **
# MAE:  0.5175311056475944
# MAPE:  33.63010479908413
# RMSE:  0.5251144380115881

# %% [markdown]
# ### Predict

# %%
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# %%
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)
y_next_30_days = model.predict(x_next_30_days)

# %%
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [0.92055615 0.91914781 0.91773946 0.91633111 0.91492276 0.91351441
#  0.91210606 0.91069771 0.90928937 0.90788102 0.90647267 0.90506432
#  0.90365597 0.90224762 0.90083927 0.89943093 0.89802258 0.89661423
#  0.89520588 0.89379753 0.89238918 0.89098083 0.88957248 0.88816414
#  0.88675579 0.88534744 0.88393909 0.88253074 0.88112239 0.87971404]

# %%
plt.plot(train_data.index, train_data['Price'])
plt.plot(test_data.index, test_data['Price'])
plt.plot(test_data.index, y_pred)
plt.plot(last_data,y_next_30_days)
plt.legend(['Train', 'Test', 'Predictions','Next30Day'])
plt.show()

# %% [markdown]
# # Heating Oil

# %% [markdown]
# ## 9:1

# %%
df= pd.read_csv('Heating Oil Futures Historical Data.csv')
df = df.dropna() # Drop missing values

# %% [markdown]
# ### Các hàm chuyển kiểu dữ liệu cho Vol, Change, Date

# %%
def convert_volume_to_number(volume_str):
    if isinstance(volume_str, float):
        return volume_str
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    else:
        return volume_str


def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%'))
    return new_change

def convert_str_to_number(str):
    return float(str.replace(',', ''))

df['Vol.'] = df['Vol.'] .apply(convert_volume_to_number)
df['Change %'] = df['Change %'].apply(convert_change_to_number)
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1319 entries, 0 to 1381
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1319 non-null   datetime64[ns]
#  1   Price     1319 non-null   float64
#  2   Open      1319 non-null   float64
#  3   High      1319 non-null   float64
#  4   Low       1319 non-null   float64
#  5   Vol.      1319 non-null   int64
#  6   Change %  1319 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 82.4 KB

# %% [markdown]
# ### Tạo hàm Eval

# %%
def eval(test,pred):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

# %%
# Chuyển đổi cột 'Price' thành mảng NumPy
df = df[['Price']]
df = df.dropna() # Drop missing values
df = df.reset_index(drop=True) # Reset the index
df
# Out:
#        Price
# 0     2.5986
# 1     2.6218
# 2     2.6786
# 3     2.6534
# 4     2.6688
# ...      ...
# 1314  1.8270
# 1315  1.7784
# 1316  1.7692
# 1317  1.7420
# 1318  1.7006
#
# [1319 rows x 1 columns]

# %% [markdown]
# ### Train, Test

# %%
# Split the data into training, testing, and validation sets
train_size = int(0.9 * len(df))
test_size = len(df)-train_size
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]

# %% [markdown]
# ### Tạo và huấn luyện mô hình

# %%
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Price'])

# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Price'])
y_pred = model.predict(x_test)

# %% [markdown]
# ### Eval

# %%
eval(y_test,y_pred)
# Out:
# ** Testing **
# MAE:  0.7267261641595276
# MAPE:  36.97784099851904
# RMSE:  0.734712545027135

# %% [markdown]
# ### Predict

# %%
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# %%
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)
y_next_30_days = model.predict(x_next_30_days)

# %%
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [1.11620415 1.1144661  1.11272805 1.11099    1.10925195 1.1075139
#  1.10577585 1.1040378  1.10229975 1.1005617  1.09882365 1.0970856
#  1.09534755 1.0936095  1.09187145 1.0901334  1.08839535 1.0866573
#  1.08491925 1.0831812  1.08144315 1.0797051  1.07796705 1.076229
#  1.07449096 1.07275291 1.07101486 1.06927681 1.06753876 1.06580071]

# %%
plt.plot(train_data.index, train_data['Price'])
plt.plot(test_data.index, test_data['Price'])
plt.plot(test_data.index, y_pred)
plt.plot(last_data,y_next_30_days)
plt.legend(['Train', 'Test', 'Predictions','Next30Day'])
plt.show()
