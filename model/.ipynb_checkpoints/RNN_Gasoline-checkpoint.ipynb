# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_log_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input

# %% [markdown]
# # Cruide Oil WTI

# %% [markdown]
# ## 7:3

# %%
# Đọc dữ liệu
df = pd.read_csv('../dataset/Crude Oil WTI.csv')

# %%
# Tiền xử lý dữ liệu
# Chuyển đổi cột 'Date' thành kiểu dữ liệu datetime
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#            Date  Price   Open   High    Low     Vol. Change %
# 0    2024-05-31  76.99  77.91  78.62  76.67  345.12K   -1.18%
# 1    2024-05-30  77.91  79.28  79.42  77.63  373.78K   -1.67%
# 2    2024-05-29  79.23  80.26  80.62  78.99  259.59K   -0.75%
# 3    2024-05-28  79.83  77.81  80.29  77.69  334.07K    1.50%
# 4    2024-05-27  78.65  77.84  78.80  77.75      NaN    1.20%
# ...         ...    ...    ...    ...    ...      ...      ...
# 1381 2019-03-07  56.66  56.20  56.99  56.08  628.82K    0.78%
# 1382 2019-03-06  56.22  56.28  56.40  55.42  637.68K   -0.60%
# 1383 2019-03-05  56.56  56.45  57.19  56.09  538.40K   -0.05%
# 1384 2019-03-04  56.59  55.83  57.00  55.81  549.40K    1.42%
# 1385 2019-03-01  55.80  57.22  57.88  55.57  684.19K   -2.48%
#
# [1386 rows x 7 columns]

# %%
# Chuyển đổi cột 'Vol.' thành số
# Chuyển đổi cột 'Change %' thành số
def convert_volume_to_number(volume_str):
    if isinstance(volume_str, float):
        return volume_str
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    else:
        return volume_str


def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%'))
    return new_change

def convert_str_to_number(str):
    return float(str.replace(',', ''))

df['Vol.'] = df['Vol.'] .apply(convert_volume_to_number)
df['Change %'] = df['Change %'].apply(convert_change_to_number)

# Đảo ngược dữ liệu để dự đoán giá trị trong tương lai
df = df.iloc[::-1].reset_index(drop=True)

# %%
# Chuyển đổi cột 'Price' thành mảng NumPy
df = df.dropna() # Drop missing values
df = df.reset_index(drop=True) # Reset the index
df
# Out:
#            Date  Price   Open   High    Low      Vol.  Change %
# 0    2019-03-01  55.80  57.22  57.88  55.57  684190.0     -2.48
# 1    2019-03-04  56.59  55.83  57.00  55.81  549400.0      1.42
# 2    2019-03-05  56.56  56.45  57.19  56.09  538400.0     -0.05
# 3    2019-03-06  56.22  56.28  56.40  55.42  637680.0     -0.60
# 4    2019-03-07  56.66  56.20  56.99  56.08  628820.0      0.78
# ...         ...    ...    ...    ...    ...       ...       ...
# 1296 2024-05-24  77.72  77.04  78.05  76.15  299080.0      1.11
# 1297 2024-05-28  79.83  77.81  80.29  77.69  334070.0      1.50
# 1298 2024-05-29  79.23  80.26  80.62  78.99  259589.0     -0.75
# 1299 2024-05-30  77.91  79.28  79.42  77.63  373780.0     -1.67
# 1300 2024-05-31  76.99  77.91  78.62  76.67  345120.0     -1.18
#
# [1301 rows x 7 columns]

# %%
# Tạo dữ liệu giả cho các ngày cuối tuần thiếu
def fill_missing_weekends(df):
    weekend_data = pd.DataFrame(columns=df.columns)
    all_dates = pd.date_range(start=df['Date'].min(), end=df['Date'].max(), freq='D')
    for date in all_dates:
        # Kiểm tra xem ngày đó có trong dữ liệu không
        if date not in df['Date'].values:
            # Nếu không có, tìm ngày trước và sau đó trong dữ liệu
            previous_day = df[df['Date'] < date]
            next_day = df[df['Date'] > date]
            # Kiểm tra DataFrame có dữ liệu không
            if not previous_day.empty and not next_day.empty:
                previous_day = previous_day.iloc[-1]
                next_day = next_day.iloc[0]
                # Tính toán giá trị trung bình của các cột (trừ cột 'Date')
                new_row_values = (previous_day.drop('Date') + next_day.drop('Date')) / 2
                # Tạo một Series mới với ngày và giá trị mới
                new_row = pd.Series([date] + new_row_values.tolist(), index=df.columns)
                # Thêm dòng dữ liệu vào DataFrame mới
                weekend_data.loc[len(weekend_data)] = new_row

    # Kết hợp dữ liệu gốc và dữ liệu cuối tuần giả mạo
    df = pd.concat([df, weekend_data], ignore_index=True)
    df.sort_values(by='Date', inplace=True)
    df.reset_index(drop=True, inplace=True)
    return df

# Áp dụng hàm để điền giá trị cho các ngày cuối tuần
df = fill_missing_weekends(df)

# %%
price = df['Price'].values
price = price.reshape(-1, 1)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
price_scaled = scaler.fit_transform(price)

# %%
train_size = int(len(price_scaled) * 0.7)
test_size = int(len(price_scaled) * 0.3)
train_data = price_scaled[:train_size]
test_data = price_scaled[train_size:train_size+test_size]

# %%
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:i + look_back, 0])
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 20

X_train, Y_train = create_dataset(train_data, look_back)
X_test, Y_test = create_dataset(test_data, look_back)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Xây dựng mô hình RNN
model = Sequential()
model.add(Input(shape=(look_back, 1)))
model.add(SimpleRNN(50, return_sequences=True))
model.add(SimpleRNN(50, return_sequences=True))
model.add(SimpleRNN(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 11. Huấn luyện mô hình
model.fit(X_train, Y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1678
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0039
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.6127e-04
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8887e-04
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.8855e-04
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8065e-04
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6904e-04
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.6508e-04
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2794e-04
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.5367e-04
# Epoch 14/100
# ...

# %%
# Dự báo
test_predict = model.predict(X_test)
test_predict = scaler.inverse_transform(test_predict.reshape(-1, 1))
Y_test = scaler.inverse_transform([Y_test])
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step

# %%
# Tính toán RMSE, MAPE và MAE trên tập test
test_score_rmse = np.sqrt(mean_squared_error(Y_test[0], test_predict[:, 0]))
test_score_mape = mean_absolute_percentage_error(Y_test[0], test_predict[:, 0]) * 100
test_score_mae = mean_absolute_error(Y_test[0], test_predict[:, 0])

print('RMSE trên tập test là:', test_score_rmse)
print('MAPE trên tập test là:', test_score_mape, '%')
print('MAE trên tập test là:', test_score_mae)
# Out:
# RMSE trên tập test là: 2.453891971393018
# MAPE trên tập test là: 2.8292650382381797 %
# MAE trên tập test là: 2.2087217088304083

# %%
# Predict next 30 days
next_30_days = []
last_30_days = price_scaled[-look_back:]

for i in range(30):
    x = last_30_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_30_days.append(y_hat[0, 0])
    last_30_days = np.append(last_30_days, y_hat)[-look_back:]

next_30_days = np.array(next_30_days).reshape(-1, 1)
next_30_days = scaler.inverse_transform(next_30_days)

# Prepare for next 60 days prediction
next_60_days = []
last_60_days = np.append(price_scaled[-look_back:], scaler.transform(next_30_days.reshape(-1, 1)))

for i in range(30):
    x = last_60_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_60_days.append(y_hat[0, 0])
    last_60_days = np.append(last_60_days, y_hat)[-look_back:]

next_60_days = np.array(next_60_days).reshape(-1, 1)
next_60_days = scaler.inverse_transform(next_60_days)

# Prepare for next 90 days prediction
next_90_days = []
last_90_days = np.append(price_scaled[-look_back:], scaler.transform(np.append(next_30_days, next_60_days).reshape(-1, 1)))

for i in range(30):
    x = last_90_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_90_days.append(y_hat[0, 0])
    last_90_days = np.append(last_90_days, y_hat)[-look_back:]

next_90_days = np.array(next_90_days).reshape(-1, 1)
next_90_days = scaler.inverse_transform(next_90_days)

# DataFrames for plotting
next_30_days_df = pd.DataFrame(next_30_days, columns=['Price'])
next_60_days_df = pd.DataFrame(next_60_days, columns=['Price'])
next_90_days_df = pd.DataFrame(next_90_days, columns=['Price'])

next_30_index = range(len(df), len(df) + 30)
next_60_index = range(len(df) + 30, len(df) + 60)
next_90_index = range(len(df) + 60, len(df) + 90)

next_30_days_df.index = next_30_index
next_60_days_df.index = next_60_index
next_90_days_df.index = next_90_index
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# ...

# %%
# Plotting
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_30_days_df, label='Next30days')
plt.plot(next_60_days_df, label='Next60days')
plt.plot(next_90_days_df, label='Next90days')
plt.legend()
plt.savefig('RNN_Cruide_Oil_73.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(30), next_30_days, label='Next30Days', color='green')
plt.plot(range(30, 60), next_60_days, label='Next60Days', color='blue')
plt.plot(range(60, 90), next_90_days, label='Next90Days', color='red')
plt.title('Price Prediction for the Next 90 Days')
plt.xlabel('Day')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.savefig('Combined_RNN_Cruide_Oil_73.png')
plt.show()

# %% [markdown]
# ## 8:2

# %%
train_size = int(len(price_scaled) * 0.8)
test_size = int(len(price_scaled) * 0.2)
train_data = price_scaled[:train_size]
test_data = price_scaled[train_size:train_size+test_size]

# %%
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:i + look_back, 0])
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 20

X_train, Y_train = create_dataset(train_data, look_back)
X_test, Y_test = create_dataset(test_data, look_back)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Xây dựng mô hình RNN
model = Sequential()
model.add(Input(shape=(look_back, 1)))
model.add(SimpleRNN(50, return_sequences=True))
model.add(SimpleRNN(50, return_sequences=True))
model.add(SimpleRNN(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Huấn luyện mô hình
model.fit(X_train, Y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1975
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0034
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2163e-04
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8823e-04
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5337e-04
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6291e-04
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.0557e-04
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1967e-04
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5430e-04
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3972e-04
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6630e-04
# Epoch 14/100
# ...

# %%
# Dự báo
test_predict = model.predict(X_test)
test_predict = scaler.inverse_transform(test_predict.reshape(-1, 1))
Y_test = scaler.inverse_transform([Y_test])
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step

# %%
# Tính toán RMSE, MAPE và MAE trên tập test
test_score_rmse = np.sqrt(mean_squared_error(Y_test[0], test_predict[:, 0]))
test_score_mape = mean_absolute_percentage_error(Y_test[0], test_predict[:, 0]) * 100
test_score_mae = mean_absolute_error(Y_test[0], test_predict[:, 0])

print('RMSE trên tập test là:', test_score_rmse)
print('MAPE trên tập test là:', test_score_mape, '%')
print('MAE trên tập test là:', test_score_mae)
# Out:
# RMSE trên tập test là: 1.2896008132895336
# MAPE trên tập test là: 1.2276192590478991 %
# MAE trên tập test là: 0.9598985303137926

# %%
# Predict next 30 days
next_30_days = []
last_30_days = price_scaled[-look_back:]

for i in range(30):
    x = last_30_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_30_days.append(y_hat[0, 0])
    last_30_days = np.append(last_30_days, y_hat)[-look_back:]

next_30_days = np.array(next_30_days).reshape(-1, 1)
next_30_days = scaler.inverse_transform(next_30_days)

# Prepare for next 60 days prediction
next_60_days = []
last_60_days = np.append(price_scaled[-look_back:], scaler.transform(next_30_days.reshape(-1, 1)))

for i in range(30):
    x = last_60_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_60_days.append(y_hat[0, 0])
    last_60_days = np.append(last_60_days, y_hat)[-look_back:]

next_60_days = np.array(next_60_days).reshape(-1, 1)
next_60_days = scaler.inverse_transform(next_60_days)

# Prepare for next 90 days prediction
next_90_days = []
last_90_days = np.append(price_scaled[-look_back:], scaler.transform(np.append(next_30_days, next_60_days).reshape(-1, 1)))

for i in range(30):
    x = last_90_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_90_days.append(y_hat[0, 0])
    last_90_days = np.append(last_90_days, y_hat)[-look_back:]

next_90_days = np.array(next_90_days).reshape(-1, 1)
next_90_days = scaler.inverse_transform(next_90_days)

# DataFrames for plotting
next_30_days_df = pd.DataFrame(next_30_days, columns=['Price'])
next_60_days_df = pd.DataFrame(next_60_days, columns=['Price'])
next_90_days_df = pd.DataFrame(next_90_days, columns=['Price'])

next_30_index = range(len(df), len(df) + 30)
next_60_index = range(len(df) + 30, len(df) + 60)
next_90_index = range(len(df) + 60, len(df) + 90)

next_30_days_df.index = next_30_index
next_60_days_df.index = next_60_index
next_90_days_df.index = next_90_index
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# ...

# %%
# Plotting
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_30_days_df, label='Next30days')
plt.plot(next_60_days_df, label='Next60days')
plt.plot(next_90_days_df, label='Next90days')
plt.legend()
plt.savefig('RNN_Cruide_Oil_82.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(30), next_30_days, label='Next30Days', color='green')
plt.plot(range(30, 60), next_60_days, label='Next60Days', color='blue')
plt.plot(range(60, 90), next_90_days, label='Next90Days', color='red')
plt.title('Price Prediction for the Next 90 Days')
plt.xlabel('Day')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.savefig('Combined_RNN_Cruide_Oil_73.png')
plt.show()

# %% [markdown]
# ### 9:1

# %%
train_size = int(len(price_scaled) * 0.9)
test_size = int(len(price_scaled) * 0.1)
train_data = price_scaled[:train_size]
test_data = price_scaled[train_size:train_size+test_size]

# %%
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:i + look_back, 0])
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 20

X_train, Y_train = create_dataset(train_data, look_back)
X_test, Y_test = create_dataset(test_data, look_back)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Xây dựng mô hình RNN
model = Sequential()
model.add(Input(shape=(look_back, 1)))
model.add(SimpleRNN(50, return_sequences=True))
model.add(SimpleRNN(50, return_sequences=True))
model.add(SimpleRNN(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 11. Huấn luyện mô hình
model.fit(X_train, Y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1663
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2449e-04
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4290e-04
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6050e-04
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5616e-04
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5282e-04
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3530e-04
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6029e-04
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9225e-04
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4030e-04
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8583e-04
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2226e-04
# Epoch 14/100
# ...

# %%
# Dự báo
test_predict = model.predict(X_test)
test_predict = scaler.inverse_transform(test_predict.reshape(-1, 1))
Y_test = scaler.inverse_transform([Y_test])
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step

# %%
# Tính toán RMSE, MAPE và MAE trên tập test
test_score_rmse = np.sqrt(mean_squared_error(Y_test[0], test_predict[:, 0]))
test_score_mape = mean_absolute_percentage_error(Y_test[0], test_predict[:, 0]) * 100
test_score_mae = mean_absolute_error(Y_test[0], test_predict[:, 0])

print('RMSE trên tập test là:', test_score_rmse)
print('MAPE trên tập test là:', test_score_mape, '%')
print('MAE trên tập test là:', test_score_mae)
# Out:
# RMSE trên tập test là: 1.1571841166926087
# MAPE trên tập test là: 1.1577652437617594 %
# MAE trên tập test là: 0.9011820903577279

# %%
# Predict next 30 days
next_30_days = []
last_30_days = price_scaled[-look_back:]

for i in range(30):
    x = last_30_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_30_days.append(y_hat[0, 0])
    last_30_days = np.append(last_30_days, y_hat)[-look_back:]

next_30_days = np.array(next_30_days).reshape(-1, 1)
next_30_days = scaler.inverse_transform(next_30_days)

# Prepare for next 60 days prediction
next_60_days = []
last_60_days = np.append(price_scaled[-look_back:], scaler.transform(next_30_days.reshape(-1, 1)))

for i in range(30):
    x = last_60_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_60_days.append(y_hat[0, 0])
    last_60_days = np.append(last_60_days, y_hat)[-look_back:]

next_60_days = np.array(next_60_days).reshape(-1, 1)
next_60_days = scaler.inverse_transform(next_60_days)

# Prepare for next 90 days prediction
next_90_days = []
last_90_days = np.append(price_scaled[-look_back:], scaler.transform(np.append(next_30_days, next_60_days).reshape(-1, 1)))

for i in range(30):
    x = last_90_days[-look_back:].reshape(1, look_back, 1)
    y_hat = model.predict(x)
    next_90_days.append(y_hat[0, 0])
    last_90_days = np.append(last_90_days, y_hat)[-look_back:]

next_90_days = np.array(next_90_days).reshape(-1, 1)
next_90_days = scaler.inverse_transform(next_90_days)

# DataFrames for plotting
next_30_days_df = pd.DataFrame(next_30_days, columns=['Price'])
next_60_days_df = pd.DataFrame(next_60_days, columns=['Price'])
next_90_days_df = pd.DataFrame(next_90_days, columns=['Price'])

next_30_index = range(len(df), len(df) + 30)
next_60_index = range(len(df) + 30, len(df) + 60)
next_90_index = range(len(df) + 60, len(df) + 90)

next_30_days_df.index = next_30_index
next_60_days_df.index = next_60_index
next_90_days_df.index = next_90_index
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# ...

# %%
# Plotting
plt.plot(train_data_df, label='Train')
plt.plot(test_data_df, label='Actual Test')
plt.plot(test_predict_df, label='Predicted Test')
plt.plot(next_30_days_df, label='Next30days')
plt.plot(next_60_days_df, label='Next60days')
plt.plot(next_90_days_df, label='Next90days')
plt.legend()
plt.savefig('RNN_Cruide_Oil_91.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(30), next_30_days, label='Next30Days', color='green')
plt.plot(range(30, 60), next_60_days, label='Next60Days', color='blue')
plt.plot(range(60, 90), next_90_days, label='Next90Days', color='red')
plt.title('Price Prediction for the Next 90 Days')
plt.xlabel('Day')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.savefig('Combined_RNN_Cruide_Oil_73.png')
plt.show()
